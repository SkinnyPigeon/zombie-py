# %% [markdown]
# # Zombie Outbreak

# %% [markdown]
# Lorem ipsum

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import math
from typing import List, Dict

# %% [markdown]
# ## Population Setup

# %%
def random_starts(circle_r: int,circle_x: int,circle_y: int, pop_count: int) -> List:
    starting_points = []
    for i in range(pop_count):
        alpha = 2 * math.pi * random.random()
        r = circle_r * math.sqrt(random.random())
        x = abs(math.floor(r * math.cos(alpha) + circle_x))
        y = abs(math.floor(r * math.sin(alpha) + circle_y))
        if [x,y] not in starting_points:
            starting_points.append([x,y])
        else:
            random_starts(circle_r,circle_x,circle_y,pop_count)
    return starting_points

# %%
def generate_people(start_index: int, coords: List) -> Dict:
    people = {}
    for i in range(len(coords)):
        people[i + start_index] = {}
        people[i + start_index]['coords'] = np.full(
            (1, 2),
            np.array(coords[i])
        )
        people[i + start_index]['state'] = [0]
    return people

# %%
def setup_population(group_count: int, group_size: int) -> Dict:
    people = {}
    for i in range(1, group_count * 2, 2):
        coords = random_starts(100, group_size * i, group_size * i, group_size)
        group = generate_people(int(group_size * ((i - 1)/2)), coords)
        people.update(group)
    return people

# %% [markdown]
# ## Walls

# %%
def make_wall(start: int, end: int) -> np.array:
    """Can only do 90* or 45*"""
    start_x = start[0]
    end_x = end[0]
    start_y = start[1]
    end_y = end[1]
    xs = []
    ys = []
    for i in range(start_x, end_x + 1):
        xs.append(i)
    for i in range(start_y, end_y + 1):
        ys.append(i)
    if len(xs) > len(ys):
        for _ in range(len(xs) - 1):
            ys.append(ys[0])
    if len(ys) > len(xs):
        for _ in range(len(ys) - 1):
            xs.append(xs[0])
    return np.array(list(zip(xs, ys)))

# %% [markdown]
# ## Collision Checks

# %%
def check_boundary(coords_to_check: List) -> bool:
    bottom_left = [0,0]
    top_right = [1000,1000]
    if (coords_to_check[0] >= bottom_left[0] and 
        coords_to_check[0] <= top_right[0] and 
        coords_to_check[1] >= bottom_left[1] and 
        coords_to_check[1] <= top_right[1]):
        return True
    return False

# %%
def check_wall_collision(coords_to_check: List) -> bool:
    if len(walls) == 0:
        return True
    for wall in walls:
        for coords in wall:
            if coords_to_check[0].all() == coords.all():
                return False
    return True

# %% [markdown]
# ## Movement

# %%
def choose_direction() -> np.array:
    dirs = np.array([[0,1],[0,-1],[1,0],[-1,0]])
    return dirs[random.randrange(4)]

# %%
def take_step(index: int) -> None:
    new_coords = [people[index]['coords'][-1] + choose_direction()]
    if check_boundary(new_coords[-1]) and check_wall_collision(new_coords):
        people[index]['coords'] = np.append(people[index]['coords'], new_coords, axis=0)
        people[index]['state'].append(people[index]['state'][-1])
    else: 
        take_step(index)

# %% [markdown]
# ## Person Interactions

# %%
def check_contact(index: int) -> None:
    for key in people.keys():
        if key <= index:
            continue
        if np.array_equal(people[index]['coords'][-1], people[key]['coords'][-1]):
            check_states(index, key)

# %%
def check_states(index: int, key: int) -> None:
    person_a = people[index]
    person_b = people[key]
    if person_a['state'][-1] == 1 and person_b['state'][-1] == 0:
        bite(key)
    elif person_a['state'][-1] == 0 and person_b['state'][-1] == 1:
        bite(index)

# %%
def bite(index):
    print(index)
    print("BITTEN")
    people[index]['state'][-1] = 1
    print(count_infected())

# %%
def count_infected():
    bitten = []
    for i in people.keys():
        if people[i]['state'][-1] == 1:
            bitten.append(1)
    return len(bitten)

# %% [markdown]
# ## Probabilities

# %% [markdown]
# Coming soon

# %% [markdown]
# ## Running Simulation

# %%
people = setup_population(2, 250)
people[0]['state'][0] = 1
people[50]['state'][0] = 1
people[100]['state'][0] = 1
people[150]['state'][0] = 1
people[200]['state'][0] = 1
people[250]['state'][0] = 1
people[300]['state'][0] = 1
people[350]['state'][0] = 1
people[400]['state'][0] = 1
people[450]['state'][0] = 1
walls = []

# %%
for _ in range(10000):
    for index in people.keys():
        take_step(index)
        check_contact(index)
# Out:
# 164
# BITTEN
# 11
# 109
# BITTEN
# 12
# 407
# BITTEN
# 13
# 17
# BITTEN
# 14
# 178
# BITTEN
# 15
# 381
# BITTEN
# 16
# 235
# BITTEN
# 17
# 173
# BITTEN
# 18
# 53
# BITTEN
# 19
# 459
# BITTEN
# 20
# 160
# BITTEN
# 21
# 229
# BITTEN
# 22
# 323
# BITTEN
# 23
# 262
# BITTEN
# 24
# 86
# BITTEN
# 25
# 99
# BITTEN
# 26
# 309
# BITTEN
# 27
# 267
# BITTEN
# 28
# 329
# BITTEN
# 29
# 477
# BITTEN
# 30
# 24
# BITTEN
# 31
# 117
# BITTEN
# 32
# 474
# BITTEN
# 33
# 176
# BITTEN
# 34
# 415
# BITTEN
# 35
# 274
# BITTEN
# 36
# 108
# BITTEN
# 37
# 92
# BITTEN
# 38
# 234
# BITTEN
# 39
# 231
# BITTEN
# 40
# 488
# BITTEN
# 41
# 421
# BITTEN
# 42
# 237
# BITTEN
# 43
# 67
# BITTEN
# 44
# 71
# BITTEN
# 45
# 349
# BITTEN
# 46
# 167
# BITTEN
# 47
# 79
# BITTEN
# 48
# 269
# BITTEN
# 49
# 360
# BITTEN
# 50
# 369
# BITTEN
# 51
# 128
# BITTEN
# 52
# 76
# BITTEN
# 53
# 233
# BITTEN
# 54
# 37
# BITTEN
# 55
# 440
# BITTEN
# 56
# 203
# BITTEN
# 57
# 205
# BITTEN
# 58
# 171
# BITTEN
# 59
# 469
# BITTEN
# 60
# 265
# BITTEN
# 61
# 347
# BITTEN
# 62
# 155
# BITTEN
# 63
# 471
# BITTEN
# 64
# 297
# BITTEN
# 65
# 42
# BITTEN
# 66
# 344
# BITTEN
# 67
# 156
# BITTEN
# 68
# 461
# BITTEN
# 69
# 411
# BITTEN
# 70
# 122
# BITTEN
# 71
# 366
# BITTEN
# 72
# 20
# BITTEN
# 73
# 80
# BITTEN
# 74
# 211
# BITTEN
# 75
# 2
# BITTEN
# 76
# 27
# BITTEN
# 77
# 254
# BITTEN
# 78
# 218
# BITTEN
# 79
# 209
# BITTEN
# 80
# 290
# BITTEN
# BITTEN
# 378
# 353
# BITTEN
# 379
# 311
# BITTEN
# 380
# 243
# BITTEN
# 381
# 408
# BITTEN
# 382
# 447
# BITTEN
# 383
# 375
# BITTEN
# 384
# 161
# BITTEN
# 385
# 481
# BITTEN
# 386
# 112
# BITTEN
# 387
# 319
# BITTEN
# 388
# 489
# BITTEN
# 389
# 295
# BITTEN
# 390
# 337
# BITTEN
# 391
# 358
# BITTEN
# 392
# 335
# BITTEN
# 393
# 354
# BITTEN
# 394
# 334
# BITTEN
# 395
# 97
# BITTEN
# 396
# 355
# BITTEN
# 397
# 317
# BITTEN
# 398
# 153
# BITTEN
# 399
# 242
# BITTEN
# 400
# 195
# BITTEN
# 401
# 222
# BITTEN
# 402
# 36
# BITTEN
# 403
# 338
# BITTEN
# 404
# 204
# BITTEN
# 405
# 460
# BITTEN
# 406
# 306
# BITTEN
# 407
# 428
# BITTEN
# 408
# 232
# BITTEN
# 409
# 215
# BITTEN
# 410
# 330
# BITTEN
# 411
# 372
# BITTEN
# 412
# 442
# BITTEN
# 413
# 163
# BITTEN
# 414
# 302
# BITTEN
# 415
# 483
# BITTEN
# 416
# 402
# BITTEN
# 417
# 77
# BITTEN
# 418
# 352
# BITTEN
# 419
# 484
# BITTEN
# 420
# 73
# BITTEN
# 421
# 468
# BITTEN
# 422
# 380
# BITTEN
# 423
# 467
# BITTEN
# 424
# 284
# BITTEN
# 425
# 268
# BITTEN
# 426
# 359
# BITTEN
# 427
# 283
# BITTEN
# 428
# 491
# BITTEN
# 429
# 277
# BITTEN
# 430
# 305
# BITTEN
# 431
# 322
# BITTEN
# 432
# 246
# BITTEN
# 433
# 197
# BITTEN
# 434
# 308
# BITTEN
# 435
# 368
# BITTEN
# 436
# 301
# BITTEN
# 437
# 456
# BITTEN
# 438
# 70
# BITTEN
# 439
# 398
# BITTEN
# 440
# 423
# BITTEN
# 441
# 339
# BITTEN
# 442
# 270
# BITTEN
# 443
# 343
# BITTEN
# 444
# 383
# BITTEN
# 445
# 405
# BITTEN
# 446
# 346
# BITTEN
# 447
# 417
# BITTEN
# 448
# 279
# BITTEN
# 449
# 363
# BITTEN
# 450
# 441
# BITTEN
# 451
# 342
# BITTEN
# 452
# 148
# BITTEN
# 453
# 387
# BITTEN
# 454
# 281
# BITTEN
# 455

# %%
people[0]
# Out:
# {'coords': array([[196, 225],
#         [197, 225],
#         [196, 225],
#         ...,
#         [205, 266],
#         [205, 265],
#         [204, 265]]),
#  'state': [1]}

# %%
coords = random_starts(100, 250 * 1, 250 * 1, 250)
coords = np.array(coords)
plt.scatter(coords[:,0],coords[:,1])

# %% [markdown]
# ## Useful Reminders

# %%
# coords_1 = np.array(group_1)
# coords_2 = np.array(group_2)
# coords = np.append(coords_1, coords_2, axis=0)

# %%
# plt.scatter(coords[:,0], coords[:,1])
# plt.plot(wall[:,0],wall[:,1])

# %%
# wall = make_wall([3,0], [3,500])
# walls = [wall]
